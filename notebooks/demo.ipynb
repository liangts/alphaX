# %%
import sys
import pandas as pd
sys.path.append("/mnt/d/Dev/alphaX/")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(sys.path)
# Out:
# ['/mnt/d/Dev/alphaX/notebooks', '/home/liang/.vscode-server/extensions/ms-toolsai.jupyter-2020.12.414227025/pythonFiles', '/home/liang/.vscode-server/extensions/ms-toolsai.jupyter-2020.12.414227025/pythonFiles/lib/python', '/home/liang/miniconda3/envs/alpha/lib/python38.zip', '/home/liang/miniconda3/envs/alpha/lib/python3.8', '/home/liang/miniconda3/envs/alpha/lib/python3.8/lib-dynload', '', '/home/liang/.local/lib/python3.8/site-packages', '/home/liang/miniconda3/envs/alpha/lib/python3.8/site-packages', '/home/liang/miniconda3/envs/alpha/lib/python3.8/site-packages/IPython/extensions', '/home/liang/.ipython', '/mnt/d/Dev/alphaX/']

# %%
from alphax.src.api.base import TimeSeriesAPI

ts = TimeSeriesAPI()
ts.plot(symbol="AAPL")

# %%
from alphax.src.api.base import TechIndicatorsAPI

ti = TechIndicatorsAPI()
ti.plot(symbol="AAPL")

# %%
from alphax.src.api.base import FundamentalDataAPI

fd = FundamentalDataAPI()
data, metadata = fd.get_earnings("MSFT")
data['totalRevenue'] = pd.to_numeric(data['totalRevenue'],errors='coerce')
data['fiscalDateEnding'] = pd.to_datetime(data['fiscalDateEnding'])
data.set_index('fiscalDateEnding', inplace=True)

fd.plot(title='test', df=data, cols='totalRevenue')

# %%
fd.plot(title='test', df=data, cols=['totalRevenue', 'grossProfit'] )
