# %%
import sys
import pandas as pd
sys.path.append("/mnt/d/Dev/alphaX/")

# %load_ext autoreload
# %autoreload 2

# %%
from alphax.src.tools.indicator.macd import MACD

amd_macd = MACD("amd")
df_amd, _ = amd_macd.get_MACD()

intel_macd = MACD("INTC")
df_intc, _ = intel_macd.get_MACD()

# %%
amd_macd.plot(df_amd, time_start="20210101", time_end="20210120", title="AMD MACD", cols=["MACD"])
amd_macd.plot(df_amd.diff(), time_start="20210101", time_end="20210120", title="df1 AMD MACD", cols=["MACD"])

# %%
intel_macd.plot(df_intc, time_start="20210101", time_end="20210120", title="INTC MACD", cols=["MACD"])
intel_macd.plot(df_intc.diff(), time_start="20210101", time_end="20210120", title="df1 INTC MACD", cols=["MACD"])
